# %%
from google.colab import files
import pandas as pd
import io




UploadedFile = files.upload()
# Out:
#      <input type="file" id="files-0adcf5a8-2bca-4a60-88e6-12ba1c843982" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0adcf5a8-2bca-4a60-88e6-12ba1c843982">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#1. Generate a dataframe based on tge given dataset
import pandas as pd
import io
csv = pd.read_csv(io.BytesIO(UploadedFile['HarryPotterGrades Dataset.csv']))

print(csv)
# Out:
#                   Name  Potions  Defense Against the Dark Arts  \
# 0         Harry Potter       85                             92
# 1     Hermione Granger       91                             90
# 2          Ron Weasley       92                             86
# 3         Draco Malfoy       84                             80
# 4   Neville Longbottom       89                             84
# 5          Dean Thomas       84                             84
# 6      Seamus Finnigan       91                             86
# 7       Lavender Brown       83                             83
# 8         Fred Weasley       90                             80
# 9          Oliver Wood       76                             89
# 10          Katie Bell       75                             88
# 11       Parvati Patil       90                             85
# 12        Romilda Vane       75                             78
# 13       Luna Lovegood       80                             81
# ...

# %%
#2. Computer for the mean, and median of herbology and transifiguration

print("The Mean of Herbology is  : ", csv['Herbology'].mean())
print("The Median of Herbology is :  ", csv['Herbology'].median())
print("The Mean of Transifiguration is : ", csv['Transfiguration'].mean())
print("The Median of Transifiguration is :  ", csv['Transfiguration'].median())
# Out:
# The Mean of Herbology is  :  86.93333333333334
# The Median of Herbology is :   86.0
# The Mean of Transifiguration is :  87.8
# The Median of Transifiguration is :   87.0

# %%
#3. Coputer for the Mean, Median of Potions, Defense against the dark Arts and Care of Magical Creatures

print("The Mean of Potions is  : ", csv['Potions'].mean())
print("The Median of Potions is :  ", csv['Potions'].median())
print("The Mean of Defense Against the Dark Arts is : ", csv['Defense Against the Dark Arts'].mean())
print("The Median of Defense Against the Dark Arts is :  ", csv['Defense Against the Dark Arts'].median())
# Out:
# The Mean of Potions is  :  85.33333333333333
# The Median of Potions is :   85.0
# The Mean of Defense Against the Dark Arts is :  84.66666666666667
# The Median of Defense Against the Dark Arts is :   84.0

# %%
#4. compute for standard Deviation of Herbology, and transfiguration

print("The Std of Herbology is  : ", csv['Herbology'].std())
print("The Std of transfiguration is :  ", csv['Transfiguration'].std())
# Out:
# The Std of Herbology is  :  5.560918046852473
# The Std of transfiguration is :   3.3423687066852117

# %%
#5 Compute for 80% of potions
percent1 = csv['Potions'].quantile(0.8)
print("The 80% of Potions is : ", percent1)
# Out:
# The 80% of Potions is  91.0

# %%
#6 Compute for 90%  of Defense Against the Dark Arts

percent1 = csv['Defense Against the Dark Arts'].quantile(0.9)
print("The 90% of Defense Against the Dark Arts is : ", percent1)
# Out:
# The 90% of Defense Against the Dark Arts is :  89.6

# %%
#7 Compute for 85% of Herbology
percent1 = csv['Herbology'].quantile(0.85)
print("The 85% of Potions is : ", percent1)
# Out:
# The 85% of Potions is :  92.8

# %% [markdown]
# 8. Describe the dispersion of the dataset

# %% [markdown]
# 9. based on the item 2, are they anypossible outliers?
#
# -yes there are possible outliers

# %%
#10. generate z-scores for each subject
import pandas as pd


subjects = ['Potions', 'Defense Against the Dark Arts', 'Care of Magical Creatures', 'Transfiguration', 'Herbology']
data_for_zscores = csv[subjects]

print(data_for_zscores.apply(lambda x: (x - x.mean()) / x.std()))
# Out:
#      Potions  Defense Against the Dark Arts  Care of Magical Creatures  \
# 0  -0.051031                       1.844344                   1.372710
# 1   0.867528                       1.341341                   0.343177
# 2   1.020621                       0.335335                   0.857944
# 3  -0.204124                      -1.173674                  -0.686355
# 4   0.561341                      -0.167668                  -0.171589
# 5  -0.204124                      -0.167668                   0.857944
# 6   0.867528                       0.335335                   0.343177
# 7  -0.357217                      -0.419169                   1.887476
# 8   0.714435                      -1.173674                   0.085794
# 9  -1.428869                       1.089840                  -0.171589
# 10 -1.581962                       0.838338                  -0.686355
# 11  0.714435                       0.083834                  -1.715887
# ...

# %% [markdown]
# 11. What is the z-score of the student who performed well in the subject "Potion" ?
#
#
# -the student who performed well in the subject potion is Alicia Spinnet who got a grade of 95 and a zscore of 1.479900
#
#
# -

# %% [markdown]
# 12. what is hermione's z-score in care of "Magical Creatures"? is it above or below the mean? Did she perform well in that subject?
#
#
# -Hermione , He did good at Defense Against the Dark Arts and Transfiguration and Care of Magical Creatures and got a middle of the mean in Herbology and potions overall he did great at the subjects.

# %% [markdown]
# 13. What is the z-score of the student who performed the least in herbology? who is the student?
#
#
#
# -the student who performed the least in herbology is Romilda Vane and he/she got  a z-score of  -2.145929

# %% [markdown]
# 14. who excelled in the subject 'Transfiguration'? what is her z score?
#
#
# - the student who excelled in the subject 'Transfiguration' is Hermione Granger who got a grade of 95 and a z score of 2.154161

# %% [markdown]
# 15. what is neville longbottom's performace in terms of his z score in all of his subject compared to his classmates? did he do well in 4 subject areas?
#
# -Neville Longbottom's performance is below avarage aside of the subject potions, and he did not do well in  Defense Against the Dark Arts, Care of Magical Creatures, Transfiguration   , and Herbology

# %%
#test 2

#1 THE PROBABILITY OF RAIN ON A GIVEN DAY IS 30% and the probability of wind is 40% if the probability of both rain and wind occuring on the same day is 20%, what is the probability that there will be either rain or wind?


k = 0.30
n = 0.40
p = 0.20

probability = k + n - p

print('The probability that there will be either rain or wind is : ' , probability)
# Out:
# The probability that there will be either rain or wind is :  0.49999999999999994

# %%
#2. A fruit basket contains 10 apples, 8 oranges , 5 bananas, since a fruit cannot be both an apple and an orange , what is the probability of picking either an apple or an orrange?

apple = 10
oranges = 8
banana = 5

probability  = apple + oranges  / 23

print('The probability of either picking apple or banana is ', probability )
# Out:
# The probability of either picking apple or banana is  10.347826086956522
