# %%
import pandas as pd



data={
    'Name': ['Juan Dela Cruz', 'Mark Reyes', 'Christ Reyes', 'Angela Delgado', 'Sam Medina' ],
    'AGE': [20,21,19,20,22],
    'COURSE': ['CS','IT','EE','ECE','COE'],
    'YEAR': [2,3,1,2,4],


}
ambot = pd.DataFrame(data)

# %%
print(ambot['AGE'].min())
# Out:
# 19

# %%
print(ambot['AGE'].mode())
# Out:
# 0    20
# Name: AGE, dtype: int64

# %%
print(ambot['AGE'].median())
# Out:
# 20.0

# %%
print(ambot['AGE'].mean())
# Out:
# 20.4

# %%
data2={
      'Course': ['BSCS','BSIT','BSCOE','BSECE','BSEE','BSA','BSBA','BSCRIM'],
      'First Year': [35,90,85,54,54,110,150,175],
      'Second Year': [20,75,64,48,60,85,120,130],
      'Third Year': [18,70,60,40,58,80,110,110],
      'Fourth Year': [18,68,56,35,50,75,105,98],


}

ambot2 = pd.DataFrame(data2)
ambot2['Total'] = ambot2[['First Year', 'Second Year', 'Third Year', 'Fourth Year']].sum(axis=1)
ambot2.set_index('Course')['Total'].plot(kind = 'pie' )
# Out:
# <Axes: ylabel='Total'>

# %%
print(ambot2['First Year'].min,ambot2['Second Year'].min,ambot2['Third Year'].min,ambot2['Fourth Year'].min)
# Out:
# <bound method Series.min of 0     35
# 1     90
# 2     85
# 3     54
# 4     54
# 5    110
# 6    150
# 7    175
# Name: First Year, dtype: int64> <bound method Series.min of 0     20
# 1     75
# 2     64
# 3     48
# 4     60
# 5     85
# 6    120
# 7    130
# Name: Second Year, dtype: int64> <bound method Series.min of 0     18
# 1     70
# 2     60
# 3     40
# 4     58
# 5     80
# 6    110
# 7    110
# Name: Third Year, dtype: int64> <bound method Series.min of 0     18
# 1     68
# 2     56
# 3     35
# 4     50
# 5     75
# 6    105
# 7     98
# Name: Fourth Year, dtype: int64>

# %%
print("mean",ambot2['First Year'].mean,ambot2['Second Year'].mean,ambot2['Third Year'].mean,ambot2['Fourth Year'].mean)
# Out:
# mean <bound method Series.mean of 0     35
# 1     90
# 2     85
# 3     54
# 4     54
# 5    110
# 6    150
# 7    175
# Name: First Year, dtype: int64> <bound method Series.mean of 0     20
# 1     75
# 2     64
# 3     48
# 4     60
# 5     85
# 6    120
# 7    130
# Name: Second Year, dtype: int64> <bound method Series.mean of 0     18
# 1     70
# 2     60
# 3     40
# 4     58
# 5     80
# 6    110
# 7    110
# Name: Third Year, dtype: int64> <bound method Series.mean of 0     18
# 1     68
# 2     56
# 3     35
# 4     50
# 5     75
# 6    105
# 7     98
# Name: Fourth Year, dtype: int64>

# %%
print(ambot2['First Year'].mode,ambot2['Second Year'].mode,ambot2['Third Year'].mode,ambot2['Fourth Year'].mode)
# Out:
# <bound method Series.mode of 0     35
# 1     90
# 2     85
# 3     54
# 4     54
# 5    110
# 6    150
# 7    175
# Name: First Year, dtype: int64> <bound method Series.mode of 0     20
# 1     75
# 2     64
# 3     48
# 4     60
# 5     85
# 6    120
# 7    130
# Name: Second Year, dtype: int64> <bound method Series.mode of 0     18
# 1     70
# 2     60
# 3     40
# 4     58
# 5     80
# 6    110
# 7    110
# Name: Third Year, dtype: int64> <bound method Series.mode of 0     18
# 1     68
# 2     56
# 3     35
# 4     50
# 5     75
# 6    105
# 7     98
# Name: Fourth Year, dtype: int64>

# %%
print(ambot2['First Year'].median,ambot2['Second Year'].median,ambot2['Third Year'].median,ambot2['Fourth Year'].median)
# Out:
# <bound method Series.median of 0     35
# 1     90
# 2     85
# 3     54
# 4     54
# 5    110
# 6    150
# 7    175
# Name: First Year, dtype: int64> <bound method Series.median of 0     20
# 1     75
# 2     64
# 3     48
# 4     60
# 5     85
# 6    120
# 7    130
# Name: Second Year, dtype: int64> <bound method Series.median of 0     18
# 1     70
# 2     60
# 3     40
# 4     58
# 5     80
# 6    110
# 7    110
# Name: Third Year, dtype: int64> <bound method Series.median of 0     18
# 1     68
# 2     56
# 3     35
# 4     50
# 5     75
# 6    105
# 7     98
# Name: Fourth Year, dtype: int64>

# %%
print(ambot2['First Year'].mode,ambot2['Second Year'].mode,ambot2['Third Year'].mode,ambot2['Fourth Year'].mode)

# %%
ambot['Age'].plot(kind=box)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-7aad5fb75ffe> in <cell line: 1>()
# ----> 1 ambot['Age'].plot(kind=box)
#
# ...
