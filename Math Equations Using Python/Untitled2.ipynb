# %%
import pandas as pd
import numpy as np

# Create example data
data = {
    'x': np.linspace(0, 10, 100),
    'y': np.sin(np.linspace(0, 10, 100))
}
df = pd.DataFrame(data)

# Plot the data
df.plot(title='Sine Wave Plot', ylabel='y-axis', xlabel='x-axis')
# Out:
# <Axes: title={'center': 'Sine Wave Plot'}, xlabel='x-axis', ylabel='y-axis'>
