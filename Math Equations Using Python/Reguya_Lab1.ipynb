# %%
import pandas as pd

#1 Creating Dictionary
data = {
    'Name': ['Juan Dela Cruz', 'Mark Reyes', 'Chris Lopez', 'Angela Lopez', 'Sam Medina'],
    'Subject': ['CCE 101/L','CCE 101/L','CCE 101/L','CCE 101/L','CCE 101/L'],
    'Grade': [89,86,88,92,88],
    'Number of days present': [3,1,2,2,1],
    'Number of days absent': [7,4,5,0,2],
}

# %%
#2
generated = pd.DataFrame(data)
print(generated)
# Out:
#              Name    Subject  Grade  Number of days present  \
# 0  Juan Dela Cruz  CCE 101/L     89                       3
# 1      Mark Reyes  CCE 101/L     86                       1
# 2     Chris Lopez  CCE 101/L     88                       2
# 3    Angela Lopez  CCE 101/L     92                       2
# 4      Sam Medina  CCE 101/L     88                       1
#
#    Number of days absent
# 0                      7
# 1                      4
# 2                      5
# 3                      0
# 4                      2

# %% [markdown]
# 3. Describe the data frame
#
# -First Thing i do is i created a dictionary and from that i converted from dictionary to dataframe, by using the library pandas, and i passed the result of the converted datafram to my variable name 'generated' and printed it

# %%
#4
print("\nthe mean for grade is: " , generated['Grade'].mean())
print("\nthe median for grade is: " , generated['Grade'].median())
print("\nthe std for grade is: " , generated['Grade'].std())
print("\nthe var for grade is: " , generated['Grade'].var())
print("\nthe mean for Number of days Present is: " , generated['Number of days present'].mean())
print("\nthe std for Number of days Present is: " , generated['Number of days present'].std())
print("\nthe var for Number of days Present is: " , generated['Number of days present'].var())
print("\nthe median for Number of days present  is: " , generated['Number of days present'].median())
print("\nthe mean for Number of days absent is: " , generated['Number of days absent'].mean())
print("\nthe std for Number of days absent is: " , generated['Number of days absent'].std())
print("\nthe var for Number of days absent is: " , generated['Number of days absent'].var())
print("\nthe median for Number of days absent  is: " , generated['Number of days absent'].median())
# Out:
# the mean for grade is:  88.6
#
# the median for grade is:  88.0
#
# the std for grade is:  2.1908902300206643
#
# the var for grade is:  4.8
#
# the mean for Number of days Present is:  1.8
#
# the std for Number of days Present is:  0.8366600265340756
#
# the var for Number of days Present is:  0.7000000000000001
#
# the median for Number of days present  is:  2.0
#
# the mean for Number of days absent is:  3.6
#
# the std for Number of days absent is:  2.701851217221259
#
# the var for Number of days absent is:  7.300000000000001
#
# the median for Number of days absent  is:  4.0

# %% [markdown]
# 5. Interpret the result.
#
# i get all the mean,median,mode, std , var by
#
# mean(), median(), mode(), std(), var()
#
# in mean addind all values in my age, number of days absent, and number of days present, sum it all up,
