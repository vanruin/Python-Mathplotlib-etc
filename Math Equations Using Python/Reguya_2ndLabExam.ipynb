# %%
#1 In a survey 40% of students like math 50% like Science, and 20% like both

#A. WHat is the probability that randomly selected student like either Math or Science?(code)

math = 0.40
science = 0.50
both = 0.20


either = math + science - both

print('The probability that a randomly selected student likes either math or science is:', either)
# Out:
# The probability that a randomly selected student likes either math or science is: 0.7

# %% [markdown]
# **B. Is it likely or Unlikely?**
#
# The probabiliy that randomly selected student likes either math or science is  0.7 , which indicates that its more likely they like either math or science

# %%
#2. A bag contains 3 red balls and 5 blue balls, wo balls are drawing one after another without replacement

#. A What is the probability that both balls are red ?
red = 3
blue = 5
total = red + blue


firstred = red / total


secondfirst = (red - 1) / (total - 1)


BothRed = firstred * secondfirst

print('The probability that both balls are red is:', BothRed)
# Out:
# The probability that both balls are red is: 0.10714285714285714

# %% [markdown]
# **B. Is it likely or Unlikely? (explain):**
#
# The probabiliy that Both balls is red is 0.10714285714285714 , this indicates that it is very unlikely that both balls is red

# %%
#3 In a group of students 60% plays basketball , 40% play soccess and 25% play both

#A.what is the probability that a randomly chosen student plays either basketball or soccerr


basketball = 0.60
soccer = 0.40
both = 0.25

total = basketball +  soccer  - both

print('The probabiliy that randomly chosen student either play basketball or soccerr is   : ', total)
# Out:
# The probabiliy that randomly chosen student either play basketball or soccerr is   :  0.75

# %% [markdown]
# B. Is it Likely Or Unlikely?
#
# The probability of randomly chosent student either play basketball or Soccerr is : 0.75 , this indicates that it is more unlikely that the chosent student play either basketball or soccerr

# %%
import numpy as np
import matplotlib.pyplot as plt
#4. in a network of 20 computers each has 30% chance of being infected with a virus




#B. Create probability mass function PMF

n = 20
p = 0.30
k = 2

probability = binom.pmf(k, n, p)
print(f"The probability of exactly 2 computers being infected is: {probability:.4f}")
print('------------------------------------------------------------------------------')

#C. Create Graph


x = np.arange(0, n + 1)


pmf_values = binom.pmf(x, n, p)

# Create the graph
plt.bar(x, pmf_values)
plt.xlabel("Number of Infected Computers")
plt.ylabel("Probability")
plt.title("Probability Mass Function for Infected Computers")
plt.show()
# Out:
# The probability of exactly 2 computers being infected is: 0.0278
# ------------------------------------------------------------------------------

# %% [markdown]
# **A. What is the PRobability that exactly 2 computers are infected? **
#
# Answer: the probability that exactly 2 computers are infected is L 0.0278 , this indicates that it is more unlikely that 2 computers are infected.
#
# **D. Describe the shape of your graph**
#
# Answer : The graph i created is Bar graph and it say that middle somewhere 5 - 6 computers are infected
#
# **E. is it likely or unlikely ? **
#
#
# Answer : it is likely that 5 - 7 computers are infected

# %%
import numpy as np
from scipy.stats import binom
# 5. A company implements a two factor authentication(2fa) system that has an 85% success rate for each login attempt



#B. Create probability mass function (pmf) (code)

n = 8
p = 0.85


x = np.arange(0, n + 1)


pmf_values = binom.pmf(x, n, p)


print(f"PMF values: {pmf_values}")


#C. Create Graph(code)

plt.bar(x, pmf_values)
plt.xlabel("Number of Successful Attempts")
plt.ylabel("Probability")
plt.title("Probability Mass Function for 2FA Login Attempts")
plt.show()
# Out:
# PMF values: [2.56289063e-07 1.16184375e-05 2.30432344e-04 2.61156656e-03
#  1.84985965e-02 8.38603041e-02 2.37604195e-01 3.84692506e-01
#  2.72490525e-01]

# %% [markdown]
# **A. If an Employee tries to log in 8 times, what is the probability that exactly 6 attemps are successful(word)**
#
# Answer: The probability is 8.38603041e-02 , and it say that it is more likely that the user who tries to log in 8 times 6 attempts are Successfull
#
#
# **D. Describe the shape of your Graph(word)**
#
# Answer: In this Graph i Create a Bar Graph, and it say 6 - 8 attempts may be SuccessFul
#
# **E. is it likely or unlikely(word)**
#
#
# it is likely that an employee trist to log in 8 times , and 6 attemps maybe successful

# %%
#6. A biased coin has a 0.7 probability of landing heads


#B. Create Probability Mass Function PMF(Code):

n = 8
p = 0.7

x = np.arange(0, n + 1)


pmf_values = binom.pmf(x, n, p)

print('PMF: ', pmf_values)

#C. Create  a Graph

plt.bar(x, pmf_values)
plt.xlabel("Coin is tossed")
plt.ylabel("Probability")
plt.title("Probability Mass Function for  tossing a coin 5 times and getting exactly 3 heads")
plt.show()
# Out:
# PMF:  [6.5610000e-05 1.2247200e-03 1.0001880e-02 4.6675440e-02 1.3613670e-01
#  2.5412184e-01 2.9647548e-01 1.9765032e-01 5.7648010e-02]

# %% [markdown]
# A. If the coin is tossed 5 times , what is the probability of getting extactly 3?
#
# Answer :  1.0001880e-02
#
# C. Describe your graph
#
# - I created a bar graph type of graph and this indicates that out of 5 times tossed coints getting 3 heads is pretty high
#
#
# E. Is it likely or Unlikely?
#
# it is likely that getting 3 heads in 5 time tossed coint is high
